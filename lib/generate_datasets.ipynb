# %%
from sklearn import datasets
from matplotlib.colors import ListedColormap

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_2d_dataset(data, colors):
    pyplot.figure(figsize(8, 8))
    pyplot.scatter(list(map(lambda x: x[0], data[0])), list(map(lambda x: x[1], data[0])), c = data[1], cmap = colors)

# %%
#2 окружности точек
circles = datasets.make_circles()

plot_2d_dataset(circles, ListedColormap(['red', 'yellow']))

# %%
#генерация датаседа для классификации
simple_classification_problem = datasets.make_classification(n_features = 2, n_informative = 2, n_classes = 4, 
                                                              n_redundant = 0, n_clusters_per_class = 1, random_state = 1)

plot_2d_dataset(simple_classification_problem, ListedColormap(['red', 'blue', 'green', 'yellow']))

# %%
#генерация датаседа для регрессии
reg_data, reg_target = datasets.make_regression(n_features = 2, n_informative = 1, n_targets = 1, 
                                                noise = 5., random_state = 7)

plot_2d_dataset([reg_data, reg_target], ListedColormap(['red', 'blue']))

# %%
# Out:
# [(array([-1.17998209, -0.30019374]), -19.415498282216713),
#  (array([-1.83242597, -1.07798489]), -67.48034683833052),
#  (array([-0.52460462,  0.26941163]), 15.146288579923615),
#  (array([ 0.69729411, -0.19385632]), -19.98364429902627),
#  (array([-0.74906574,  0.27343882]), 24.711022073310925),
#  (array([ 1.29688519, -0.29971124]), -14.94811907504194),
#  (array([ 1.6995373 , -0.09961063]), -5.542388399459355),
#  (array([-1.12196239, -0.53085375]), -28.692432965943006),
#  (array([-0.59076982, -0.19602731]), -15.021176343730062),
#  (array([0.23730185, 1.91201886]), 114.32915135741034),
#  (array([ 0.7587252 , -1.55628765]), -101.81138022280363),
#  (array([0.13062298, 0.63711283]), 33.70588715276634),
#  (array([ 0.38538654, -0.47841788]), -24.638127964770746),
#  (array([-1.77801285, -0.19285546]), -8.341353866858512),
#  (array([-1.33652055,  0.08815492]), -0.9552422537951726),
#  (array([-0.1799864 ,  0.84073324]), 50.389494892470964),
# ...
